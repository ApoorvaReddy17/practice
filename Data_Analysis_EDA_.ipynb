# %% [markdown]
# <a href="https://colab.research.google.com/github/ApoorvaReddy17/practice/blob/main/Data_Analysis_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required Liabraries
import pandas as pd
import numpy as np

# %%
# Loading the Dataset
df=pd.read_csv('data.csv', encoding='ISO-8859-1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# number of rows and columns
df.shape
# Out:
# (541909, 8)

# %%
# Access first five rows
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Access last five rows
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# displaying total columns from dataset
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# getting all columns one by one
for column in df.columns:
  print(column)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %%
# Renameing columns names
d={'InvoiceNo':"invoice_num",
'StockCode':"stock_code",
'Description':"description",
'Quantity':"quantity",
'InvoiceDate':"invoice_date",
'UnitPrice':"unit_price",
'CustomerID':"cust_id",
'Country':"country"}
d
# Out:
# {'InvoiceNo': 'invoice_num',
#  'StockCode': 'stock_code',
#  'Description': 'description',
#  'Quantity': 'quantity',
#  'InvoiceDate': 'invoice_date',
#  'UnitPrice': 'unit_price',
#  'CustomerID': 'cust_id',
#  'Country': 'country'}

# %%
df.rename(columns=d,inplace=True)

# %%
# After changing column names Checking new column names
df.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'cust_id', 'country'],
#       dtype='object')

# %% [markdown]
# # **Data Cleaning**

# %%
#  ----   Data Cleaning   -------
# checking column types
df.dtypes
# Out:
# invoice_num      object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# cust_id         float64
# country          object
# dtype: object

# %%
# Data frame information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# checking type of invoice_date column
df.dtypes
# Out:
# invoice_num      object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# cust_id         float64
# country          object
# dtype: object

# %%
# Access intial data
df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                 WHITE METAL LANTERN         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %%
# converting invoice_date data type into datetime data type
df['invoice_date']=pd.to_datetime(df['invoice_date'], format='%m/%d/%Y %H:%M')
df
# Out:
#        invoice_num stock_code                          description  quantity  \
# 0           536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1           536365      71053                  WHITE METAL LANTERN         6
# 2           536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3           536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4           536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...            ...        ...                                  ...       ...
# 541904      581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905      581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906      581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907      581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908      581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
df.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %%
# let us check description column
df['description']
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: object

# %%
# convert description column inputs into lowercase
df['description']=df['description'].str.lower()
df
# Out:
#        invoice_num stock_code                          description  quantity  \
# 0           536365     85123A   white hanging heart t-light holder         6
# 1           536365      71053                  white metal lantern         6
# 2           536365     84406B       cream cupid hearts coat hanger         8
# 3           536365     84029G  knitted union flag hot water bottle         6
# 4           536365     84029E       red woolly hottie white heart.         6
# ...            ...        ...                                  ...       ...
# 541904      581587      22613          pack of 20 spaceboy napkins        12
# 541905      581587      22899         children's apron dolly girl          6
# 541906      581587      23254        childrens cutlery dolly girl          4
# 541907      581587      23255      childrens cutlery circus parade         4
# 541908      581587      22138        baking set 9 piece retrospot          3
#
# ...

# %% [markdown]
# ## **Missing Values**

# %%
# Checking missing values for each column
df.isnull()
# Out:
#         invoice_num  stock_code  description  quantity  invoice_date  \
# 0             False       False        False     False         False
# 1             False       False        False     False         False
# 2             False       False        False     False         False
# 3             False       False        False     False         False
# 4             False       False        False     False         False
# ...             ...         ...          ...       ...           ...
# 541904        False       False        False     False         False
# 541905        False       False        False     False         False
# 541906        False       False        False     False         False
# 541907        False       False        False     False         False
# 541908        False       False        False     False         False
#
#         unit_price  cust_id  country
# 0            False    False    False
# 1            False    False    False
# ...

# %%
# checking missing values count on each column
df.isnull().sum()
# Out:
# invoice_num          0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# cust_id         135080
# country              0
# dtype: int64

# %%
# checking missing values count on each column, applying sorting
df.isnull().sum().sort_values()
# Out:
# invoice_num          0
# stock_code           0
# quantity             0
# invoice_date         0
# country              0
# unit_price           0
# description       1454
# cust_id         135080
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# cust_id         135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %% [markdown]
# ### **Dropping missing values**

# %%
# Treating Missing values (Based on team meeting/client discussion)
df_new = df.dropna()
df_new.isnull().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# cust_id         0
# country         0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %%
# converting cust_id float type to intger type
df_new['cust_id'] = df_new['cust_id'].astype('int64')
df_new.head()
# Out:
# <ipython-input-26-694aaa580a1b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['cust_id'] = df_new['cust_id'].astype('int64')
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# ...

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-31 11:48:00       1.950000
# 75%        12.000000            2011-10-20 13:06:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       248.693370                            NaN      69.315162
#
#              cust_id
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price    cust_id
# count  406829.00                         406829   406829.00  406829.00
# mean       12.06  2011-07-10 16:30:57.879207424        3.46   15287.69
# min    -80995.00            2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00            2011-04-06 15:02:00        1.25   13953.00
# 50%         5.00            2011-07-31 11:48:00        1.95   15152.00
# 75%        12.00            2011-10-20 13:06:00        3.75   16791.00
# max     80995.00            2011-12-09 12:50:00    38970.00   18287.00
# std       248.69                            NaN       69.32    1713.60

# %% [markdown]
# ## **removing negative values from quantity column**

# %%
# conclusion : quantity column have some negative values
# we need to remove negative values
con = df_new.quantity > 0
con
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: quantity, Length: 406829, dtype: bool

# %%
df_new = df_new[con]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   397924 non-null  object
#  1   stock_code    397924 non-null  object
#  2   description   397924 non-null  object
#  3   quantity      397924 non-null  int64
#  4   invoice_date  397924 non-null  datetime64[ns]
#  5   unit_price    397924 non-null  float64
#  6   cust_id       397924 non-null  int64
#  7   country       397924 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.3+ MB

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price    cust_id
# count  397924.00                         397924   397924.00  397924.00
# mean       13.02  2011-07-10 23:43:36.912475648        3.12   15294.32
# min         1.00            2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00            2011-04-07 11:12:00        1.25   13969.00
# 50%         6.00            2011-07-31 14:39:00        1.95   15159.00
# 75%        12.00            2011-10-20 14:33:00        3.75   16795.00
# max     80995.00            2011-12-09 12:50:00     8142.75   18287.00
# std       180.42                            NaN       22.10    1713.17

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# ## **Adding the column 'amount_spent'**

# %%
df_new['amount_spent'] = df_new['quantity'] * df_new['unit_price']
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34

# %% [markdown]
# ## **Rearranging columns for more readability**

# %%
col_order = ['invoice_num','invoice_date','stock_code','description','quantity','unit_price','amount_spent','cust_id','country']
df_new = df_new[col_order]
df_new.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %% [markdown]
# ## **Accessing year and month value from invoice_date**

# %%
year = df_new['invoice_date'].dt.year
month = df_new.invoice_date.dt.month
print(year,month)
df_new.insert(loc = 2, column = 'month', value = month) # adding month column
df_new
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: invoice_date, Length: 397924, dtype: int32
#        invoice_num        invoice_date  month stock_code  \
# 0           536365 2010-12-01 08:26:00     12     85123A
# 1           536365 2010-12-01 08:26:00     12      71053
# 2           536365 2010-12-01 08:26:00     12     84406B
# 3           536365 2010-12-01 08:26:00     12     84029G
# 4           536365 2010-12-01 08:26:00     12     84029E
# ...            ...                 ...    ...        ...
# 541904      581587 2011-12-09 12:50:00     12      22613
# 541905      581587 2011-12-09 12:50:00     12      22899
# ...

# %%
# v1 = df_new['invoice_date'].map(lambda col: 100 * (col.year) + col.month)
v1 = 100 * (year) + month
df_new.insert(loc = 2, column = 'year_month', value = v1)

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month  month stock_code  \
# 0           536365 2010-12-01 08:26:00      201012     12     85123A
# 1           536365 2010-12-01 08:26:00      201012     12      71053
# 2           536365 2010-12-01 08:26:00      201012     12     84406B
# 3           536365 2010-12-01 08:26:00      201012     12     84029G
# 4           536365 2010-12-01 08:26:00      201012     12     84029E
# ...            ...                 ...         ...    ...        ...
# 541904      581587 2011-12-09 12:50:00      201112     12      22613
# 541905      581587 2011-12-09 12:50:00      201112     12      22899
# 541906      581587 2011-12-09 12:50:00      201112     12      23254
# 541907      581587 2011-12-09 12:50:00      201112     12      23255
# 541908      581587 2011-12-09 12:50:00      201112     12      22138
#
#                                 description  quantity  unit_price  \
# 0        white hanging heart t-light holder         6        2.55
# ...

# %% [markdown]
# ## **Day of the week**
#  In pandas, the day formate starts from 0 to 6
#
#  Monday = 0, Tuesday = 1 .... Sunday = 6
#
#  Apply +1 to make Monday = 1.....until Sunday = 7

# %%
v2 = df_new.invoice_date.dt.dayofweek
v3 = v2 + 1
df_new.insert(loc = 4, column = 'day', value = v3)
df_new
v2.unique(),v2
# Out:
# (array([2, 3, 4, 6, 0, 1], dtype=int32),
#  0         2
#  1         2
#  2         2
#  3         2
#  4         2
#           ..
#  541904    4
#  541905    4
#  541906    4
#  541907    4
#  541908    4
#  Name: invoice_date, Length: 397924, dtype: int32)

# %%
v3.unique(),v3
# Out:
# (array([3, 4, 5, 7, 1, 2], dtype=int32),
#  0         3
#  1         3
#  2         3
#  3         3
#  4         3
#           ..
#  541904    5
#  541905    5
#  541906    5
#  541907    5
#  541908    5
#  Name: invoice_date, Length: 397924, dtype: int32)

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# ...

# %%
df_new.insert(loc = 5, column = 'hour', value = df_new.invoice_date.dt.hour)
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## **Groupby**

# %%
# groupby customer_id
df_new.groupby(by = ['cust_id']).count()
# Out:
#          invoice_num  invoice_date  year_month  month  day  hour  stock_code  \
# cust_id
# 12346              1             1           1      1    1     1           1
# 12347            182           182         182    182  182   182         182
# 12348             31            31          31     31   31    31          31
# 12349             73            73          73     73   73    73          73
# 12350             17            17          17     17   17    17          17
# ...              ...           ...         ...    ...  ...   ...         ...
# 18280             10            10          10     10   10    10          10
# 18281              7             7           7      7    7     7           7
# 18282             12            12          12     12   12    12          12
# 18283            756           756         756    756  756   756         756
# 18287             70            70          70     70   70    70          70
#
# ...

# %%
# groupby using cust_id and country
df_new.groupby(by = ['cust_id', 'country']).count()
# Out:
#                         invoice_num  invoice_date  year_month  month  day  \
# cust_id country
# 12346   United Kingdom            1             1           1      1    1
# 12347   Iceland                 182           182         182    182  182
# 12348   Finland                  31            31          31     31   31
# 12349   Italy                    73            73          73     73   73
# 12350   Norway                   17            17          17     17   17
# ...                             ...           ...         ...    ...  ...
# 18280   United Kingdom           10            10          10     10   10
# 18281   United Kingdom            7             7           7      7    7
# 18282   United Kingdom           12            12          12     12   12
# 18283   United Kingdom          756           756         756    756  756
# 18287   United Kingdom           70            70          70     70   70
#
# ...

# %%
df_new.groupby(by = ['cust_id', 'country'])['invoice_num'].count()
# Out:
# cust_id  country
# 12346    United Kingdom      1
# 12347    Iceland           182
# 12348    Finland            31
# 12349    Italy              73
# 12350    Norway             17
#                           ...
# 18280    United Kingdom     10
# 18281    United Kingdom      7
# 18282    United Kingdom     12
# 18283    United Kingdom    756
# 18287    United Kingdom     70
# Name: invoice_num, Length: 4347, dtype: int64

# %%
# as_index = False
df_new.groupby(by =['cust_id','country'], as_index=False)['invoice_num'].count()
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %% [markdown]
# ## **Data Visualization**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **number of orders form different customers**

# %%
orders = df_new.groupby (by=['cust_id','country'], as_index=False)['invoice_num'].count()
orders
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
plt.subplots(figsize = (15,6))
plt.plot(orders.cust_id, orders.invoice_num)
plt.xlabel('Customer ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for Different Customers')
plt.show()

# %% [markdown]
# **check top 5 most no of orders**

# %%
orders.sort_values(by='invoice_num', ascending=False).head()
# Out:
#       cust_id         country  invoice_num
# 4019    17841  United Kingdom         7847
# 1888    14911            EIRE         5677
# 1298    14096  United Kingdom         5111
# 334     12748  United Kingdom         4596
# 1670    14606  United Kingdom         2700

# %% [markdown]
# ### **Money spent by each customers**

# %%
df_new.groupby(by=['cust_id','country'])['amount_spent'].sum()
# Out:
# cust_id  country
# 12346    United Kingdom    77183.60
# 12347    Iceland            4310.00
# 12348    Finland            1797.24
# 12349    Italy              1757.55
# 12350    Norway              334.40
#                              ...
# 18280    United Kingdom      180.60
# 18281    United Kingdom       80.82
# 18282    United Kingdom      178.05
# 18283    United Kingdom     2094.88
# 18287    United Kingdom     1837.28
# Name: amount_spent, Length: 4347, dtype: float64

# %%
money_spent = df_new.groupby(by=['cust_id','country'], as_index=False)['amount_spent'].sum()
money_spent
# Out:
#       cust_id         country  amount_spent
# 0       12346  United Kingdom      77183.60
# 1       12347         Iceland       4310.00
# 2       12348         Finland       1797.24
# 3       12349           Italy       1757.55
# 4       12350          Norway        334.40
# ...       ...             ...           ...
# 4342    18280  United Kingdom        180.60
# 4343    18281  United Kingdom         80.82
# 4344    18282  United Kingdom        178.05
# 4345    18283  United Kingdom       2094.88
# 4346    18287  United Kingdom       1837.28
#
# [4347 rows x 3 columns]

# %% [markdown]
# **Top 5 customers who spent highest money**

# %%
money_spent.sort_values(by='amount_spent',ascending=False).head()
# Out:
#       cust_id         country  amount_spent
# 1698    14646     Netherlands     280206.02
# 4210    18102  United Kingdom     259657.30
# 3737    17450  United Kingdom     194550.79
# 3017    16446  United Kingdom     168472.50
# 1888    14911            EIRE     143825.06

# %%
plt.subplots(figsize=(15,6))

plt.plot(money_spent.cust_id, money_spent.amount_spent)

plt.xlabel('Customer ID')
plt.ylabel('Amount Spent (Dollar)')
plt.title('Money Spent by Each Customer')

plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %% [markdown]
# ### **Number of orders in different months**

# %%
df_new.year_month.unique()
# Out:
# array([201012, 201101, 201102, 201103, 201104, 201105, 201106, 201107,
#        201108, 201109, 201110, 201111, 201112], dtype=int32)

# %%
color = sns.color_palette()

# %%
df_new.groupby('invoice_num')['year_month'].unique()
# Out:
# invoice_num
# 536365    [201012]
# 536366    [201012]
# 536367    [201012]
# 536368    [201012]
# 536369    [201012]
#             ...
# 581583    [201112]
# 581584    [201112]
# 581585    [201112]
# 581586    [201112]
# 581587    [201112]
# Name: year_month, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_num')['year_month'].unique().value_counts()
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [201109]    1756
# [201105]    1555
# [201012]    1400
# [201106]    1393
# [201107]    1331
# [201103]    1321
# [201108]    1281
# [201104]    1149
# [201102]     998
# [201101]     987
# [201112]     778
# Name: count, dtype: int64

# %%
a = df_new.groupby('invoice_num')['year_month'].unique().value_counts().sort_index()
a
# Out:
# year_month
# [201012]    1400
# [201101]     987
# [201102]     998
# [201103]    1321
# [201104]    1149
# [201105]    1555
# [201106]    1393
# [201107]    1331
# [201108]    1281
# [201109]    1756
# [201110]    1929
# [201111]    2658
# [201112]     778
# Name: count, dtype: int64

# %%
ax = a.plot(kind = 'bar', color = color[0], figsize = (15,6))

ax.set_xlabel('Month and Year', fontsize = 15)
ax.set_ylabel('Number of Orders', fontsize = 15)
ax.set_title('Number of Orders in Different Months', fontsize = 20)

t = ('Dec_10', 'Jan_11', 'Feb_11', 'Mar_11', 'Apr_11', 'May_11', 'Jun_11',
     'July_11', 'Aug_11', 'Sep_11', 'Oct_11', 'Nov_11', 'Dec_11')

ax.set_xticklabels(t, rotation = 0)

plt.show()

# %% [markdown]
# ### **Daywise orders**

# %%
b = df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index()
b
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
ax = b.plot(kind = 'bar', color = color[0], figsize = (10,6))

ax.set_xlabel('Day', fontsize = 15)
ax.set_ylabel('Number of Orders', fontsize = 15)
ax.set_title('Number of orders in different days', fontsize = 15)

d = ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Sunday')

ax.set_xticklabels(d, rotation = 'horizontal', fontsize = 10)

plt.show()

# %% [markdown]
# ### **Discover patterns for Unit Price**

# %%
df_new.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %%
# check the distribution of unit price
plt.subplots(figsize = (12,6))
sns.boxplot(df_new.unit_price)
plt.show()

# %%
# from above details we can conclude that min value for product is zero
# that is there are some free products

df_free = df_new[df_new.unit_price == 0] # filter only free products (cost = 0)
len(df_free)
# Out:
# 40

# %%
c = df_free.year_month.value_counts().sort_index()
c
# Out:
# year_month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
ax = c.plot(kind = 'bar',figsize = (15,6), color=color[0])

ax.set_xlabel('Month and Year', fontsize = 15)
ax.set_ylabel('Number of Free Products', fontsize = 15)
ax.set_title('Number of Free Products in Different Months', fontsize = 20)

t = ('Dec_10', 'Jan_11', 'Feb_11', 'Mar_11', 'Apr_11', 'May_11',
     'July_11', 'Aug_11', 'Sep_11', 'Oct_11', 'Nov_11')
ax.set_xticklabels(t, rotation = 'horizontal', fontsize = 13)

plt.show()

# %% [markdown]
# ### **Countrywise orders**

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %%
orders_countrywise = df_new.groupby('country')['invoice_num'].count().sort_values()
orders_countrywise
# Out:
# country
# Saudi Arabia                 9
# Bahrain                     17
# Czech Republic              25
# Brazil                      32
# Lithuania                   35
# Lebanon                     45
# RSA                         58
# European Community          60
# United Arab Emirates        68
# Malta                      112
# Greece                     145
# Canada                     151
# USA                        179
# Iceland                    182
# Singapore                  222
# Unspecified                244
# Israel                     248
# Japan                      321
# Poland                     330
# Denmark                    380
# Austria                    398
# Sweden                     451
# Cyprus                     614
# Finland                    685
# Channel Islands            748
# Italy                      758
# Norway                    1072
# Australia                 1185
# Portugal                  1462
# Switzerland               1842
# ...

# %%
plt.subplots(figsize = (15,8))
orders_countrywise.plot(kind = 'barh', color = color[0])
plt.xlabel('Number of Orders', fontsize = 15)
plt.ylabel('Country', fontsize = 15)
plt.title('Number of Orders in Different Countries', fontsize = 15)
plt.show()

# %%
del orders_countrywise['United Kingdom']
plt.subplots(figsize = (15,8))
orders_countrywise.plot(kind = 'barh', color = color[0])
plt.xlabel('Number of Orders', fontsize = 15)
plt.ylabel('Country', fontsize = 15)
plt.title('Number of Orders in Different Countries', fontsize = 15)
plt.show()

# %% [markdown]
# ### **money spent by each country**

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# ...

# %%
amount_spent_countrywise = df_new.groupby('country')['amount_spent'].sum().sort_values()
amount_spent_countrywise
# Out:
# country
# Saudi Arabia                145.920
# Bahrain                     548.400
# Czech Republic              826.740
# RSA                        1002.310
# Brazil                     1143.600
# European Community         1300.250
# Lithuania                  1661.060
# Lebanon                    1693.880
# United Arab Emirates       1902.280
# Unspecified                2667.070
# Malta                      2725.590
# USA                        3580.390
# Canada                     3666.380
# Iceland                    4310.000
# Greece                     4760.520
# Israel                     7221.690
# Poland                     7334.650
# Austria                   10198.680
# Cyprus                    13590.380
# Italy                     17483.240
# Denmark                   18955.340
# Channel Islands           20450.440
# Singapore                 21279.290
# Finland                   22546.080
# Portugal                  33439.890
# Norway                    36165.440
# ...

# %%
plt.subplots(figsize = (15,8))
amount_spent_countrywise.plot(kind = 'barh', color = color[0])
plt.xlabel('Amount Spent (Dollar)', fontsize = 15)
plt.ylabel('Country', fontsize = 15)
plt.title('Amount Spent in Different Countries', fontsize = 15)
plt.show()

# %%
del amount_spent_countrywise['United Kingdom']
plt.subplots(figsize = (15,8))
amount_spent_countrywise.plot(kind = 'barh', color = color[0])

plt.xlabel('Amount Spent (Dollar)', fontsize = 15)
plt.ylabel('Country', fontsize = 15)
plt.title('Amount Spent in Different Countries', fontsize = 15)
plt.show()
