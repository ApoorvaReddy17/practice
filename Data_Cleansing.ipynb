# %% [markdown]
# <a href="https://colab.research.google.com/github/ApoorvaReddy17/practice/blob/main/Data_Cleansing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required Liabraries
import pandas as pd
import numpy as np

# %%
# uncleaned data or raw data with lot of missing data and noise is called as raw data
# cleaning raw data
emp=pd.read_excel(r"Rawdata.xlsx")
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
# number of rows and columns (dimension of the dataframe)
emp.shape
# Out:
# (6, 6)

# %%
len(emp) # length or no of rows in dataframe
# Out:
# 6

# %%
# Access first five rows
emp.head()
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year

# %%
# Access last five rows
emp.tail()
# Out:
#      Name          Domain     Age   Location   Salary      Exp
# 1  Teddy^         Testing  45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#     NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics     NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics   67-yr        NaN   30000-  5+ year
# 5     Kim             NLP    55yr      Delhi  6000^$0      10+

# %%
# displaying total columns from dataset
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
emp["Name"]
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
# getting all columns one by one
for column in emp.columns:
  print(column)
  print(emp[column])
  print("*"*50)
# Out:
# Name
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object
# **************************************************
# Domain
# 0     Datascience#$
# 1           Testing
# 2    Dataanalyst^^#
# 3       Ana^^lytics
# 4        Statistics
# 5               NLP
# Name: Domain, dtype: object
# **************************************************
# Age
# 0    34 years
# 1      45' yr
# 2         NaN
# 3         NaN
# 4       67-yr
# 5        55yr
# Name: Age, dtype: object
# **************************************************
# Location
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object
# **************************************************
# Salary
# 0     5^00#0
# 1    10%%000
# 2    1$5%000
# 3     2000^0
# 4     30000-
# 5    6000^$0
# Name: Salary, dtype: object
# **************************************************
# Exp
# 0         2+
# 1         <3
# ...

# %%
emp[["Name","Domain"]]
# Out:
#      Name          Domain
# 0    Mike   Datascience#$
# 1  Teddy^         Testing
# 2   Uma#r  Dataanalyst^^#
# 3    Jane     Ana^^lytics
# 4  Uttam*      Statistics
# 5     Kim             NLP

# %% [markdown]
# # **data cleansing**

# %%
# using regex removing spl charecters from Name column
emp['Name'] = emp['Name'].str.replace(r'\W', '', regex=True)
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp['Domain']=emp['Domain'].str.replace(r'\W', '', regex=True)
emp['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
emp['Age']=emp['Age'].str.extract(r'(\d+)')
emp
# Out:
#     Name       Domain  Age   Location   Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5^00#0       2+
# 1  Teddy      Testing   45  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst  NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics   67        NaN   30000-  5+ year
# 5    Kim          NLP   55      Delhi  6000^$0      10+

# %%
emp['Salary']=emp['Salary'].str.replace(r'\W','',regex=True)
emp
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
emp['Location']=emp['Location'].str.replace(r'\W','',regex=True)
emp
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
emp['Exp']=emp['Exp'].str.extract(r'(\d+)')
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data=emp.copy()

# %%
# clean_data.to_excel("clean_data.xlsx",index=False)
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %% [markdown]
# # Handling Missing Values
# # missing value treatment

# %%
# this data contain num data and categorical data
# for num data we can replace with mean,median,mode strategy
# for categorical data we can replace with mode, KNN method

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
import numpy as np
# numpy for multidimension arrary
# pandas used for dataframes

# %%
# missing value treatment for num value
clean_data['Age']=clean_data['Age'].astype(float)
clean_data['Exp']=clean_data['Exp'].astype(float)
clean_data['Salary']=clean_data['Salary'].astype(int)
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      float64
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      int64
#  5   Exp       5 non-null      float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 420.0+ bytes

# %%
m=clean_data['Age'].mean() # m is mean of age
clean_data['Age']=clean_data['Age'].fillna(m)

# %%
clean_data
# Out:
#     Name       Domain    Age   Location  Salary   Exp
# 0   Mike  Datascience  34.00     Mumbai    5000   2.0
# 1  Teddy      Testing  45.00  Bangalore   10000   3.0
# 2   Umar  Dataanalyst  50.25        NaN   15000   4.0
# 3   Jane    Analytics  50.25   Hyderbad   20000   NaN
# 4  Uttam   Statistics  67.00        NaN   30000   5.0
# 5    Kim          NLP  55.00      Delhi   60000  10.0

# %%
n=clean_data['Exp'].mean() # n is mean of Exp
clean_data['Exp']=clean_data['Exp'].fillna(n)

# %%
clean_data
# Out:
#     Name       Domain    Age   Location  Salary   Exp
# 0   Mike  Datascience  34.00     Mumbai    5000   2.0
# 1  Teddy      Testing  45.00  Bangalore   10000   3.0
# 2   Umar  Dataanalyst  50.25        NaN   15000   4.0
# 3   Jane    Analytics  50.25   Hyderbad   20000   4.8
# 4  Uttam   Statistics  67.00        NaN   30000   5.0
# 5    Kim          NLP  55.00      Delhi   60000  10.0

# %%
# missing value treatment for cat data
x=clean_data['Location'].mode()
x
# Out:
# 0    Bangalore
# 1        Delhi
# 2     Hyderbad
# 3       Mumbai
# Name: Location, dtype: object

# %%
clean_data['Location']=clean_data['Location'].fillna(x[0])

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      float64
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 420.0+ bytes

# %%
clean_data['Name']=clean_data['Name'].astype('category')
clean_data['Domain']=clean_data['Domain'].astype('category')
clean_data['Location']=clean_data['Location'].astype('category')
clean_data['Age']=clean_data['Age'].astype('int')
clean_data['Exp']=clean_data['Exp'].astype('int')

clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      category
#  1   Domain    6 non-null      category
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      category
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
# dtypes: category(3), int64(3)
# memory usage: 938.0 bytes

# %%
# clean_data.to_excel("clean_data.xlsx",index=False)
# clean_data.to_csv("address_where_you_want_to_store\\clean_data.csv",index=False)
clean_data.to_csv("clean_data.csv",index=False)
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
# location where data is stored
import os
os.getcwd()
# Out:
# '/content'

# %%
import matplotlib.pyplot as plt # visualization
import seaborn as sns # advanced visualization

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: int64

# %% [markdown]
# Univariate Analysis

# %%
# distributions plot
vis1=sns.distplot(clean_data['Salary']) # univariate analysis

# %%
plt.rcParams['figure.figsize']=5,3 # to decrease or increase size

# %% [markdown]
# Outlier Ditection
#  by using distplot, histogram, boxplot and lmplot

# %%
vis1=sns.distplot(clean_data['Salary'])

# %%
vis2=plt.hist(clean_data['Salary']) # histogram

# %%
vis3=plt.hist(clean_data['Exp']) # histogram

# %%
vis4= plt.boxplot(clean_data['Salary'])

# %% [markdown]
# bivariate analysis

# %%
vis4=sns.lmplot(data=clean_data,x='Exp',y='Salary')

# %%
vis5=sns.lmplot(data=clean_data,x='Exp',y='Salary',fit_reg=False)

# %%
vis6=sns.lmplot(data=clean_data,x='Exp',y='Salary',fit_reg=True)

# %%
# Correlation
# salary and exp is positively correlated

# %% [markdown]
#  Slicing

# %%
clean_data[:] # to get all data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data[2:] # starting from index 2 to end
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data[:4] # from stating point (index 0) to index 3 (end-1 or 4-1)
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4

# %%
# divide independent and dependent variables (x,y)

# %%
x_iv=clean_data.drop(["Salary"],axis=1)

# %%
x_iv
# Out:
#     Name       Domain  Age   Location  Exp
# 0   Mike  Datascience   34     Mumbai    2
# 1  Teddy      Testing   45  Bangalore    3
# 2   Umar  Dataanalyst   50  Bangalore    4
# 3   Jane    Analytics   50   Hyderbad    4
# 4  Uttam   Statistics   67  Bangalore    5
# 5    Kim          NLP   55      Delhi   10

# %%
y_dv=clean_data["Salary"]

# %%
y_dv
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: int64

# %%
imputation=pd.get_dummies(clean_data)

# %%
imputation
# Out:
#    Age  Salary  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0   34    5000    2      False     False       True       False      False
# 1   45   10000    3      False     False      False        True      False
# 2   50   15000    4      False     False      False       False       True
# 3   50   20000    4       True     False      False       False      False
# 4   67   30000    5      False     False      False       False      False
# 5   55   60000   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  Domain_Datascience  \
# 0       False             False               False                True
# 1       False             False               False               False
# 2       False             False                True               False
# 3       False              True               False               False
# 4        True             False               False               False
# ...
